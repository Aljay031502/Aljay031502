# %% [markdown]
# <a href="https://colab.research.google.com/github/Aljay031502/Aljay031502/blob/main/maturannumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/loans.csv')

# %%
data.head()
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id  loan_start    loan_end  \
# 0      46109      home        13672       0    10243  2002-04-16  2003-12-20
# 1      46109    credit         9794       0    10984  2003-10-21  2005-07-17
# 2      46109      home        12734       1    10990  2006-02-01  2007-07-05
# 3      46109      cash        12518       1    10596  2010-12-08  2013-05-05
# 4      46109    credit        14049       1    11415  2010-07-07  2012-05-21
#
#    rate
# 0  2.15
# 1  1.25
# 2  0.68
# 3  1.24
# 4  3.13

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/loans.csv', index_col='client_id')

# %%
data.index_col=('client_id')
